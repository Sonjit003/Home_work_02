# %%
students = {
    'uid-1': {"name": "John", "surname": "Doe", "email": "john@gmail.com"},
    'uid-2': {"name": "Jane", "surname": "Doe", "email": "jane@gmail.com"},
    'uid-3': {"name": "John", "surname": "Smith", "email": None},
    'uid-4': {"name": "Jane", "surname": "Smith", "email": "jane@gmail.com"},
}

students_attendance = {
    'uid-1': [True, True, True, True, True, True, True, True, False, True],
    'uid-2': [False, False, False, True, True, False, True, True, False, True],
    'uid-3': [True, True, False, False, True, True, True, True, True, True],
    'uid-4': [False, False, False, False, True, False, True, True, False, True],
}

students_grades = {
    'uid-1': {"hw1": 10, "hw2": 8, "hw3": 9},
    'uid-2': {"hw1": 9, "hw2": 8, "hw3": 10},
    'uid-3': {"hw1": 8, "hw2": 9, "hw3": 10},
    'uid-4': {"hw1": 10, "hw2": 8, "hw3": 10},
}
def summerize_students_grade():
    average_grades = {}
       
    for Uid, grade in students_grades.items():
        students_info = students.get(Uid, {})
        name = f"{students_info.get('name', '')} {students_info.get('surname', '')}"
        average_grade = sum(grade.values())/(len(grade))
        average_grades[Uid] = {"name": name, "score":average_grade}
    return average_grades


students_average_grade = summerize_students_grade()
print(students_average_grade)

# %%
students = {
    'uid-1': {"name": "John", "surname": "Doe", "email": "john@gmail.com"},
    'uid-2': {"name": "Jane", "surname": "Doe", "email": "jane@gmail.com"},
    'uid-3': {"name": "John", "surname": "Smith", "email": None},
    'uid-4': {"name": "Jane", "surname": "Smith", "email": "jane@gmail.com"},
}

students_attendance = {
    'uid-1': [True, True, True, True, True, True, True, True, False, True],
    'uid-2': [False, False, False, True, True, False, True, True, False, True],
    'uid-3': [True, True, False, False, True, True, True, True, True, True],
    'uid-4': [False, False, False, False, True, False, True, True, False, True],
}

students_grades = {
    'uid-1': {"hw1": 10, "hw2": 8, "hw3": 9},
    'uid-2': {"hw1": 9, "hw2": 8, "hw3": 10},
    'uid-3': {"hw1": 8, "hw2": 9, "hw3": 10},
    'uid-4': {"hw1": 10, "hw2": 8, "hw3": 10},
}
def summerize_students_attendance():
    percentage_of_students = {}
    for Uid, attandance in students_attendance.items():
        student_info = students.get(Uid, {})
        name = f"{student_info.get('name', '')} {student_info.get('surname', '')}"
        
        total_student = len(attandance)
        attended_days = sum(attandance)
        percentage_of_attendance = (attended_days/total_student)*100
        percentage_of_students[Uid] = {"name": name, "attendance_per": percentage_of_attendance} 

    return percentage_of_students

s = summerize_students_attendance()
print(s)
# Out:
# {'uid-1': {'name': 'John Doe', 'attendance_per': 90.0}, 'uid-2': {'name': 'Jane Doe', 'attendance_per': 50.0}, 'uid-3': {'name': 'John Smith', 'attendance_per': 80.0}, 'uid-4': {'name': 'Jane Smith', 'attendance_per': 40.0}}

# %%
students = {
    'uid-1': {"name": "John", "surname": "Doe", "email": "john@gmail.com"},
    'uid-2': {"name": "Jane", "surname": "Doe", "email": "jane@gmail.com"},
    'uid-3': {"name": "John", "surname": "Smith", "email": None},
    'uid-4': {"name": "Jane", "surname": "Smith", "email": "jane@gmail.com"},
}

students_attendance = {
    'uid-1': [True, True, True, True, True, True, True, True, False, True],
    'uid-2': [False, False, False, True, True, False, True, True, False, True],
    'uid-3': [True, True, False, False, True, True, True, True, True, True],
    'uid-4': [False, False, False, False, True, False, True, True, False, True],
}

students_grades = {
    'uid-1': {"hw1": 10, "hw2": 8, "hw3": 9},
    'uid-2': {"hw1": 9, "hw2": 8, "hw3": 10},
    'uid-3': {"hw1": 8, "hw2": 9, "hw3": 10},
    'uid-4': {"hw1": 10, "hw2": 8, "hw3": 10},
}
def students_peformance_summary():
    students_summary = {}
    
    for student, grade in students_grades.items():
       
        student_average = sum(grade.values())/(len(grade))
        students_summary[student] = student_average
    for student, attandance in students_attendance.items():
        student_info = students.get(student, {})
        name = f"{student_info.get('name', '')} {student_info.get('surname', '')}"
        total_day = len(attandance)
        total_attened = sum(attandance)
        percentage_attendance = (total_attened/total_day)*100

        students_summary[student] = {"name":name, "score": student_average, "student_per": percentage_attendance}
    return students_summary


summary_of_student = students_peformance_summary()
print(summary_of_student)
# Out:
# {'uid-1': {'name': 'John Doe', 'score': 9.333333333333334, 'student_per': 90.0}, 'uid-2': {'name': 'Jane Doe', 'score': 9.333333333333334, 'student_per': 50.0}, 'uid-3': {'name': 'John Smith', 'score': 9.333333333333334, 'student_per': 80.0}, 'uid-4': {'name': 'Jane Smith', 'score': 9.333333333333334, 'student_per': 40.0}}

# %%
students = {
    'uid-1': {"name": "John", "surname": "Doe", "email": "john@gmail.com"},
    'uid-2': {"name": "Jane", "surname": "Doe", "email": "jane@gmail.com"},
    'uid-3': {"name": "John", "surname": "Smith", "email": None},
    'uid-4': {"name": "Jane", "surname": "Smith", "email": "jane@gmail.com"},
}

students_attendance = {
    'uid-1': [True, True, True, True, True, True, True, True, False, True],
    'uid-2': [False, False, False, True, True, False, True, True, False, True],
    'uid-3': [True, True, False, False, True, True, True, True, True, True],
    'uid-4': [False, False, False, False, True, False, True, True, False, True],
}

students_grades = {
    'uid-1': {"hw1": 10, "hw2": 8, "hw3": 9},
    'uid-2': {"hw1": 9, "hw2": 8, "hw3": 10},
    'uid-3': {"hw1": 8, "hw2": 9, "hw3": 10},
    'uid-4': {"hw1": 10, "hw2": 8, "hw3": 10},
}
def students_overall_performance():
    studen_overall_performance = {}
    
    for student, grade in students_grades.items():
        avarage_grades_score = sum(grade.values())/(len(grade))*(0.7)
        studen_overall_performance[student] = avarage_grades_score
    for student, attandance in students_attendance.items():
        student_info = students.get(student, {})
        name = f"{student_info.get('name', '')} {student_info.get('surname', '')}"

        total_day = len(attandance)
        total_attend = sum(attandance)
        percentange_attandace = ((total_attend/total_day)*100)*0.3

        studen_overall_performance[student] = {"name":name, "score": avarage_grades_score+ percentange_attandace}

    return studen_overall_performance


overall_performance = students_overall_performance()
print(overall_performance)
# Out:
# {'uid-1': {'name': 'John Doe', 'score': 33.53333333333333}, 'uid-2': {'name': 'Jane Doe', 'score': 21.53333333333333}, 'uid-3': {'name': 'John Smith', 'score': 30.53333333333333}, 'uid-4': {'name': 'Jane Smith', 'score': 18.53333333333333}}

# %%
students = {
    'uid-1': {"name": "John", "surname": "Doe", "email": "john@gmail.com"},
    'uid-2': {"name": "Jane", "surname": "Doe", "email": "jane@gmail.com"},
    'uid-3': {"name": "John", "surname": "Smith", "email": None},
    'uid-4': {"name": "Jane", "surname": "Smith", "email": "jane@gmail.com"},
}

students_attendance = {
    'uid-1': [True, True, True, True, True, True, True, True, False, True],
    'uid-2': [False, False, False, True, True, False, True, True, False, True],
    'uid-3': [True, True, False, False, True, True, True, True, True, True],
    'uid-4': [False, False, False, False, True, False, True, True, False, True],
}

students_grades = {
    'uid-1': {"hw1": 10, "hw2": 8, "hw3": 9},
    'uid-2': {"hw1": 9, "hw2": 8, "hw3": 10},
    'uid-3': {"hw1": 8, "hw2": 9, "hw3": 10},
    'uid-4': {"hw1": 10, "hw2": 8, "hw3": 10},
}

def rank_students_by_overall_peformance():
    studen_overall_performance = {}
    
    for student, grade in students_grades.items():
        avarage_grades_score = sum(grade.values())/(len(grade))*(0.7)
        studen_overall_performance[student] = avarage_grades_score
    for student, attandance in students_attendance.items():
       

        total_day = len(attandance)
        total_attend = sum(attandance)
        percentange_attandace = ((total_attend/total_day)*100)*0.3
        studen_overall_performance[student] = avarage_grades_score + percentange_attandace
        sorted_attended_score = studen_overall_performance.items()
        sorted_list = (sorted(sorted_attended_score, key=lambda x: x[1]))
        ranked_students = {}
        rank_counter = 1
        for item, score in sorted_list:
            ranked_students[item] = {"attendance_score": score, "rank": rank_counter}
            rank_counter = rank_counter+1
    return ranked_students




    

rank = rank_students_by_overall_peformance()
print(rank)
# Out:
# {'uid-4': {'attendance_score': 18.53333333333333, 'rank': 1}, 'uid-2': {'attendance_score': 21.53333333333333, 'rank': 2}, 'uid-3': {'attendance_score': 30.53333333333333, 'rank': 3}, 'uid-1': {'attendance_score': 33.53333333333333, 'rank': 4}}
